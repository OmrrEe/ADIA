# %% [markdown]
# # Statistics
# # Put into practice 1

# %% [markdown]
# ### <font color='blue'> Name: Omar Elizondo Gzz</font>
# ### <font color='blue'> ID: A01286197</font>

# %% [markdown]
# #### It's time to put your knowledge into practice. Here you will develop an activity that consists mainly in mastering databases with the use of Python. Read carefully the following indications and develop the execution, it will be the evidence that you have done your learning activity.

# %% [markdown]
# #### Development of the activity
#
# For this activity we will include a dataset related to the red variant of the Portuguese wine “Vinho Verde”. It contains physicochemical information (inputs) and sensory information (the output). Recommended for use in classificaction or regression tasks. You will find it available under the name “winequality-red.csv” and if you want to find more information you can find it in the UC Irvine Machine Learning Repository https://archive.ics.uci.edu/dataset/186/wine+quality
#
# This is the list of variables we will be working with:
# - `fixed_acidity`
# - `volatile_acidicity`
# - `citric_acid`
# - `residual_sugar`
# - `chlorides`
# - `free_sulfur_dioxide`
# - `total_sulfur_dioxide`
# - `density`
# - `pH`
# - `sulphates`
# - `alcohol`
# - `quality`
# - `color`
#
# Develop the following points in a Jupyter Notebook, trying, as much as possible, that each point is worked in a different cell. Comments in the code are always welcome, as they help a reader to understand more easily what the creator of the file programmed.

# %% [markdown]
# 1. Import the data from the “winequality-red.csv” file into your work environment on a Jupyter Notebook and display a sample in the console, not the first rows or the last rows of the data, but printing 10 randomized rows of data. Remember that it is convenient that the “csv” file and your notebook are in the same directory.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("winequality-red.csv", sep=';')

print(df.sample(10))
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1228            5.1             0.420         0.00            1.80      0.044
# 331            10.2             0.360         0.64            2.90      0.122
# 1587            5.8             0.610         0.11            1.80      0.066
# 302             8.3             0.705         0.12            2.60      0.092
# 125             9.0             0.620         0.04            1.90      0.146
# 462            11.0             0.260         0.68            2.55      0.085
# 585             7.6             0.510         0.24            2.40      0.091
# 1426            7.7             0.230         0.37            1.80      0.046
# 1003            6.8             0.360         0.32            1.80      0.067
# 298             7.2             0.650         0.02            2.30      0.094
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1228                 18.0                  88.0  0.99157  3.68       0.73
# 331                  10.0                  41.0  0.99800  3.23       0.66
# 1587                 18.0                  28.0  0.99483  3.55       0.66
# 302                  12.0                  28.0  0.99940  3.51       0.72
# 125                  27.0                  90.0  0.99840  3.16       0.70
# 462                  10.0                  25.0  0.99700  3.18       0.61
# 585                   8.0                  38.0  0.99800  3.47       0.66
# 1426                 23.0                  60.0  0.99710  3.41       0.71
# 1003                  4.0                   8.0  0.99280  3.36       0.55
# 298                   5.0                  31.0  0.99930  3.67       0.80
#
#       alcohol  quality
# 1228     13.6        7
# 331      12.5        6
# 1587     10.9        6
# 302      10.0        5
# 125       9.4        5
# 462      11.8        5
# 585       9.6        6
# 1426     12.1        6
# 1003     12.8        7
# 298       9.7        5

# %% [markdown]
# 2. Print on a console a message indicating what other variable you would have decided to measure if you were part of the wine quality research group, clearly indicating whether the information collected would be considered quantitative or qualitative. Remember the print function.

# %%
# Write the requested lines of code below
print("I would include 'grape variety' as an additional variable, being qualitative data.")
# Out:
# I would include 'grape variety' as an additional variable, being qualitative data.

# %% [markdown]
# 3. Print and find the following information: shape, column names, column data type, missing values, descriptive statistics with the describe function on both continuous and categorical data.
#
# Do it in different cells please

# %%
# Write the requested lines of code below
print("Shape:", df.shape)
# Out:
# Shape: (1599, 12)

# %%
# Write the requested lines of code below
print("Column names:", df.columns)
# Out:
# Column names: Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='str')

# %%
# Write the requested lines of code below
print("Column data type:", df.dtypes)
# Out:
# Column data type: fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
# Write the requested lines of code below
print("Missing values:", df.isnull().sum())
# Out:
# Missing values: fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
print("Descriptive (numerical):", df.describe())
# Out:
# Descriptive (numerical):        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
print("Using describe to only include object, getting categorial, gives me an error, so in other words:")

categorical_cols = df.select_dtypes(include=['object'])

if categorical_cols.shape[1] > 0:
    print(categorical_cols.describe())
else:
    print("There are no categorical (object) columns in this dataset.")
# Out:
# Using describe to only include object, getting categorial, gives me an error, so in other words:
# There are no categorical (object) columns in this dataset.

# %% [markdown]
# 3. We have talked about the importance of visualizing data. Whether the data has a normal or skewed distribution. Then import the `matplotlib.pyplot as plt` library and don't forget to use the `%matplotlib inline` line of code. Also to the variable you are using to store the data, apply the function `hist(figsize=(10,10), xrot=45)`. Finally type `plt.show()`

# %%
# Write the requested lines of code below
# %matplotlib inline

# Plot histograms
df.hist(figsize=(10,10), xrot=45)

plt.show()

# %% [markdown]
# 4. Change the name of the column 'citric acid' to 'citricacid'.

# %%
# Write the requested lines of code below
df.rename(columns={"citric acid": "citricacid"}, inplace=True)

print(df.columns)
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citricacid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='str')

# %% [markdown]
# 5. Find the number of rows with a citric acid less than 0.60 and with a pH greater than 4.0. Remember that you have already changed the column name, this will help you.

# %%
# Write the requested line of code below
filtered_rows = df[(df["citricacid"] < 0.60) & (df["pH"] > 4.0)]

print("Number of rows meeting conditions:", filtered_rows.shape[0])
# Out:
# Number of rows meeting conditions: 2

# %% [markdown]
# 6. Find in which index and the other accompanying data for the 2 instances that meet the preconditions. To do so, manipulate the following line of code.
# df.loc[(df['column_name'] >= A) & (df['column_name'] <= B)]

# %%
# Write the requested lines of code below
result = df.loc[(df['citricacid'] < 0.60) & (df['pH'] > 4.0)]

print("Rows that meet the conditions (including index and all data):")
print(result)
# Out:
# Rows that meet the conditions (including index and all data):
#       fixed acidity  volatile acidity  citricacid  residual sugar  chlorides  \
# 1316            5.4              0.74         0.0             1.2      0.041
# 1321            5.0              0.74         0.0             1.2      0.041
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1316                 16.0                  46.0  0.99258  4.01       0.59
# 1321                 16.0                  46.0  0.99258  4.01       0.59
#
#       alcohol  quality
# 1316     12.5        6
# 1321     12.5        6

# %% [markdown]
# 7. Generate a graph, showing on the “X” axis the density variable, and on the “Y” axis the pH variable. Be sure to use a transparency value less than 0.2. Add plt.xlabel('Density'), plt.ylabel('pH'), plt.grid() and plt.title('Density vs pH scatter plot')

# %%
# Write the requested lines of code below
plt.scatter(df['density'], df['pH'], alpha=0.19)

plt.xlabel('Density')
plt.ylabel('pH')
plt.title('Density vs pH scatter plot')
plt.grid()

plt.show()

# %% [markdown]
# 8. Create a boxplot for the free sulfur dioxide variable.

# %%
# Write the requested lines of code below
plt.boxplot(df['free sulfur dioxide'])

plt.title('Boxplot of Free Sulfur Dioxide')

plt.show()
